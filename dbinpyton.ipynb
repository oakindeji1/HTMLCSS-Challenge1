# %% [markdown]
# <a href="https://colab.research.google.com/github/oakindeji1/HTMLCSS-Challenge1/blob/main/dbinpyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1

# %%
print(a)
# Out:
# 1

# %%
a=5*8

# %%
print(a)
# Out:
# 40

# %%
# !pip install panda
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7239 sha256=4dea2a4f91b666248b0aa4f46cf35bbf378b3ba140abc9c6d9a1367e17811e59
#   Stored in directory: /root/.cache/pip/wheels/0e/8b/c3/ff9cbde1fffd8071cff8367a86f0350a1ce30a8d31b6a432e9
# Successfully built panda
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/sample_orders.csv')

# %%
data
# Out:
#            Date  OrderID Order Category  Order Value  Number of Items  \
# 0    2023-12-03     1161       Clothing       133.98                7
# 1    2023-12-03     7386       Clothing        14.42                4
# 2    2023-12-03     8346   Pet Supplies        15.15                1
# 3    2023-12-04     4064       Clothing       112.18                7
# 4    2023-12-04     6426       Clothing       173.48               10
# ..          ...      ...            ...          ...              ...
# 545  2024-03-01     5776    Electronics       133.66               10
# 546  2024-03-01     6699       Clothing       100.17                6
# 547  2024-03-02     1297   Pet Supplies       189.02                9
# 548  2024-03-02     9980       Clothing        66.34                3
# 549  2024-03-02     7863   Pet Supplies       190.78               10
#
#     Shipping Method  Discount %
# 0          standard          14
# 1          standard           8
# ...

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data
# Out:
#           Date  OrderID Order Category  Order Value  Number of Items  \
# 0   2023-12-03     1161       Clothing       133.98                7
# 1   2023-12-03     7386       Clothing        14.42                4
# 2   2023-12-03     8346   Pet Supplies        15.15                1
# 3   2023-12-04     4064       Clothing       112.18                7
# 4   2023-12-04     6426       Clothing       173.48               10
# ..         ...      ...            ...          ...              ...
# 545 2024-03-01     5776    Electronics       133.66               10
# 546 2024-03-01     6699       Clothing       100.17                6
# 547 2024-03-02     1297   Pet Supplies       189.02                9
# 548 2024-03-02     9980       Clothing        66.34                3
# 549 2024-03-02     7863   Pet Supplies       190.78               10
#
#     Shipping Method  Discount %
# 0          standard          14
# 1          standard           8
# 2          priority           2
# ...

# %%
sum_by_day = data.groupby('Date')['Order Value'].sum()

# %%
sum_by_day
# Out:
# Date
# 2023-12-03    163.55
# 2023-12-04    543.09
# 2023-12-05     95.66
# 2023-12-06    528.04
# 2023-12-07    666.79
#                ...
# 2024-02-27    641.08
# 2024-02-28    451.48
# 2024-02-29    826.20
# 2024-03-01    761.32
# 2024-03-02    446.14
# Name: Order Value, Length: 91, dtype: float64

# %%
electronic_data = data[data['Order Category']=="Electronics"]

# %%
electronic_daily = electronic_data.groupby('Date')['Order Value'].sum()

# %%
electronic_daily
# Out:
# Date
# 2023-12-04     41.09
# 2023-12-05     14.64
# 2023-12-06    196.14
# 2023-12-07    337.62
# 2023-12-10     80.08
#                ...
# 2024-02-26     95.69
# 2024-02-27     51.54
# 2024-02-28    121.90
# 2024-02-29    329.36
# 2024-03-01    622.19
# Name: Order Value, Length: 81, dtype: float64

# %%
pet_data = data[data['Order Category']=="Pet Supplies"]

# %%
pet_daily = pet_data.groupby('Date')['Order Value'].sum()

# %%
pet_daily
# Out:
# Date
# 2023-12-03     15.15
# 2023-12-04     24.88
# 2023-12-05     27.82
# 2023-12-06     84.07
# 2023-12-07    329.17
#                ...
# 2024-02-25    312.44
# 2024-02-27    290.75
# 2024-02-29    372.07
# 2024-03-01     22.19
# 2024-03-02    379.80
# Name: Order Value, Length: 76, dtype: float64

# %%
sum_by_day.index
# Out:
# DatetimeIndex(['2023-12-03', '2023-12-04', '2023-12-05', '2023-12-06',
#                '2023-12-07', '2023-12-08', '2023-12-09', '2023-12-10',
#                '2023-12-11', '2023-12-12', '2023-12-13', '2023-12-14',
#                '2023-12-15', '2023-12-16', '2023-12-17', '2023-12-18',
#                '2023-12-19', '2023-12-20', '2023-12-21', '2023-12-22',
#                '2023-12-23', '2023-12-24', '2023-12-25', '2023-12-26',
#                '2023-12-27', '2023-12-28', '2023-12-29', '2023-12-30',
#                '2023-12-31', '2024-01-01', '2024-01-02', '2024-01-03',
#                '2024-01-04', '2024-01-05', '2024-01-06', '2024-01-07',
#                '2024-01-08', '2024-01-09', '2024-01-10', '2024-01-11',
#                '2024-01-12', '2024-01-13', '2024-01-14', '2024-01-15',
#                '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19',
#                '2024-01-20', '2024-01-21', '2024-01-22', '2024-01-23',
# ...

# %%
sum_by_day.values
# Out:
# array([ 163.55,  543.09,   95.66,  528.04,  666.79,  125.71,  406.97,
#         375.23,  117.63,  453.09,  569.78,  375.64,  457.35,  982.02,
#         458.6 ,  228.28,  656.23,  722.05,  635.89,   37.88,  437.98,
#         699.53,  358.15,  252.57,  670.04,  379.32,  265.57,  489.92,
#         464.13,  807.52,  450.15,  574.65,  128.09, 1204.97,  673.25,
#         514.38,  453.5 ,  165.91,  301.44,  474.  ,  667.65,  377.76,
#         198.78,  183.53,  325.37,  150.3 ,  319.89,  537.23,  279.31,
#         339.97,  182.96,  635.26,  731.29,  401.17,  818.21,  735.13,
#         376.42,  484.81,  834.74,  822.92,  471.44,  559.19,  408.86,
#         977.72,  271.91,  738.46,  581.7 ,  508.24,  733.81,  557.81,
#         246.25,  453.89,  438.12,  694.56,  448.61,  710.53,  383.39,
#         976.32,  697.99,  267.09,  562.82,  462.53,  442.99,   79.29,
#        1027.21,  627.86,  641.08,  451.48,  826.2 ,  761.32,  446.14])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.plot(sum_by_day.index, sum_by_day.values)
plt.show()
